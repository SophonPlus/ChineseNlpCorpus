# %% [markdown]
# # dmsc_v2 说明
# 0. **下载地址：** [百度网盘](https://pan.baidu.com/s/1c0yn3TlkzHYTdEBz3T5arA)
# 1. **数据概览：** 28 部电影，超 70 万 用户，超 200 万条 评分/评论 数据
# 2. **推荐实验：** 推荐系统、情感/观点/评论 倾向性分析
# 2. **数据来源：**[豆瓣电影](https://movie.douban.com/)
# 3. **原数据集：** [Douban Movie Short Comments Dataset V2](https://www.kaggle.com/utmhikari/doubanmovieshortcomments)
# 4. **加工处理：**
#     1. 整理成与 [MovieLens](https://grouplens.org/datasets/movielens/) 兼容的格式
#     2. 进行脱敏操作，以保护用户隐私

# %%
import pandas as pd

# %%
path = 'dmsc_文件夹_所在_路径'

# %% [markdown]
# # 1. movies.csv

# %% [markdown]
# ## 加载数据

# %%
movies = pd.read_csv(path + 'movies.csv')

print('电影数目：%d' % movies.shape[0])
# Out:
# 电影数目：28

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | movieId | 电影 id (从 0 开始，连续编号) |
# | title | 英文名称 |
# | title_cn | 中文名称 |

# %%
movies
# Out:
#     movieId                                       title title_cn
# 0         0                      Avengers Age of Ultron   复仇者联盟2
# 1         1                        Big Fish and Begonia     大鱼海棠
# 2         2                   Captain America Civil War    美国队长3
# 3         3                              Chinese Zodiac     十二生肖
# 4         4             Chronicles of the Ghostly Tribe     九层妖塔
# 5         5                          CUG King of Heroes     大圣归来
# 6         6                               Forever Young     栀子花开
# 7         7                           Goodbye Mr. Loser    夏洛特烦恼
# 8         8                                    Iron Man     钢铁侠1
# 9         9   Journey to the West Conquering the Demons    西游降魔篇
# 10       10  Journey to the West The Demons Strike Back    西游伏妖篇
# 11       11                                  La La Land     爱乐之城
# 12       12                            Lost In Thailand       泰囧
# 13       13                                 My Sunshine    何以笙箫默
# 14       14                            Operation Mekong    湄公河行动
# 15       15                                    Soulmate    七月与安生
# 16       16                                The Avengers    复仇者联盟
# 17       17                               The Continent     后会无期
# 18       18                                  The Ghouls      寻龙诀
# 19       19                              The Great Wall       长城
# 20       20                                The Left Ear       左耳
# 21       21                                 The Mermaid      美人鱼
# 22       22                              Tiny Times 1.0     小时代1
# 23       23                              Tiny Times 3.0     小时代3
# 24       24                              Train to Busan      釜山行
# 25       25              Transformers Age of Extinction    变形金刚4
# 26       26                                   Your Name     你的名字
# 27       27                                    Zootopia    疯狂动物城

# %% [markdown]
# # 2. ratings.csv

# %% [markdown]
# ## 加载数据

# %%
ratings = pd.read_csv(path + 'ratings.csv')

print('用户数据：%d' % ratings.userId.unique().shape[0])
print('评分数目：%d' % ratings.shape[0])
# Out:
# 用户数据：738701
# 评分数目：2125056

# %% [markdown]
# ## 字段说明

# %% [markdown]
# | 字段 | 说明 |
# | ---- | ---- |
# | userId | 电影 id (从 0 开始，连续编号) |
# | movieId | 即 movies.csv 中的 movieId|
# |rating | 评分，[1,5] 之间的整数 |
# |timestamp | 评分时间戳 |
# |comment | 评论内容 |
# | like | 该评论被多少人点赞 |

# %%
ratings.sample(20)
# Out:
#          userId  movieId  rating   timestamp  \
# 815164   414816       11       5  1487520000
# 484795   284641        7       3  1457452800
# 1498155  240507       20       2  1439827200
# 963653   462588       13       2  1432915200
# 164544    68120        2       3  1462982400
# 1924245   31017       26       5  1480608000
# 1190043   23222       17       4  1406390400
# 533044   298786        7       5  1444406400
# 568834   149675        8       3  1332172800
# 1585233  621582       22       1  1372262400
# 308196   118365        5       5  1438617600
# 2049260  157216       27       5  1467043200
# 781519    12675       11       4  1487433600
# 1476968   61393       20       1  1429804800
# 1457844  242372       19       4  1481990400
# 1601069  200513       22       3  1380470400
# 657081   259172        9       5  1436803200
# 1122966   19523       16       4  1472313600
# 709490    38718       10       3  1485705600
# 1588982  321127       22       1  1373904000
#
#                                                    comment  like
# 815164    分明就是最纯粹的理想的颂曲与悲歌了，尽管有不过分的怜善和掺杂的现实。为idealists干...     1
# 484795                                     马东什么?马什么梅?什么冬梅?     0
# 1498155        三观不正的片子，故事情节薄弱，老套，所有人的演技都需要再磨练，一星给我羊，一星给苏有朋     0
# 963653                                   这演技，这编剧，这剪接，也是醉了。     0
# 164544                                            复仇与正义无关。     0
# 1924245                                           20161202     0
# 1190043                                 喜欢最后一句话 告别的时候要用力一点     0
# 533044                                                  好看     0
# 568834                                      老美的爱国主义情节千篇一律      0
# 1585233               四娘一生黑，7个女人和1个爷们的逗比故事，四娘还记得汤臣一品的朱梓骁吗？     2
# 308196                                              因为是国产的     0
# 2049260                                           受众全员的不俗套     0
# 781519    如果没有那五分钟幻想，现实中表象的平凡和美生活也就不会显露出一丝遗憾。画面特别美，尤其是月...     0
# 1476968                              这片子原来讲的是老子的青春呀，神仙打架啰？     0
# 1457844                    看到的评论。1，虎头蛇尾。2，一个老外入党的故事。个人不作评价     0
# 1601069                                    还成，不过离现实很远，有点臆想     0
# 657081                  真无语那些装逼犯。你打一星。我不能打五星。高高在上的感觉真令人作呕。     0
# 1122966   厉害在完全不混乱，我是说剧情和人物，当然，日常拆纽约，日常炸航母，日常碎斯塔克大楼。还是最...     0
# 709490                                      怀旧？吴亦凡一说台词我就尴尬     0
# 1588982   至少在我眼里，电影应当是传递一种正确的价值观，没看到四个女人的友情有多坚不可摧，也没看到他...     0

# %% [markdown]
# # 3. 用于 情感/观点/评论 倾向性分析

# %% [markdown]
# ## 筛选出带有较明显倾向性的评论（1星和5星的评分）

# %%
ratings_with_opinions = ratings[(ratings.rating==1) | (ratings.rating==5)]


print('正向（5星）数目：%d' % (ratings_with_opinions[ratings_with_opinions.rating==5].shape[0]))
print('负向（1星）数目：%d' % (ratings_with_opinions[ratings_with_opinions.rating==1].shape[0]))

ratings_with_opinions.sample(20)
# Out:
# 正向（5星）数目：638106
# 负向（1星）数目：190927
#          userId  movieId  rating   timestamp  \
# 1137050  500981       16       5  1336579200
# 509176   159303        7       1  1444060800
# 1644455  631908       22       1  1402329600
# 928956   163112       12       5  1356624000
# 1322171  248455       18       5  1450454400
# 1323406  512660       18       5  1451059200
# 1628911  627548       22       1  1375804800
# 597028   122876        9       5  1361030400
# 1615427  157129       22       5  1372262400
# 753394   396331       10       5  1485532800
# 1857108   84900       25       5  1403971200
# 1420351  374516       19       5  1481904000
# 396593    97557        5       5  1437580800
# 1791747  666311       24       5  1482595200
# 1361391  558389       18       5  1452528000
# 2019277   61331       27       5  1457712000
# 1917009  690620       26       5  1480608000
# 1711591  237081       23       1  1405526400
# 1249319   96675       17       5  1406736000
# 2067896  223297       27       5  1457539200
#
#                                                    comment  like
# 1137050                                             好好看！！！     0
# 509176                         恶心了十一假期 被水军的评论骗进了影院 以后不看豆瓣了     0
# 1644455                   真的不明白怎么有这多人买票去看这个电影，烂死了，简直比于妈还狗血     0
# 928956                                    今年最佳喜剧。现在流行大牌打酱油     0
# 1322171   我觉得这是中国电影的进步，虽然模仿好莱坞的痕迹还很明显。3D效果表现的中国式的盗墓场景，感...     0
# 1323406                                      真的不起五毛特效！还不错！     0
# 1628911                                           扭曲的男性自恋~     0
# 597028    听说豆瓣上很多文艺青年只给一颗星，我觉得他们就是在装B。在电影院看的3D版，3D效果和特效...     0
# 1615427                            结尾的彩蛋都值五分 做人只要不挑剔 绝对很欢乐     0
# 753394    自从我知道有豆瓣这个东西之后就对这没有好印象。真心觉得是屌丝装逼的圣地。非要装出一副逼格很...     0
# 1857108                                     背都看湿了，必须看IMAX的     0
# 1420351                                        还可以吧，看的挺过瘾的     0
# 396593                                      非常好看 希望下一部更加好看     0
# 1791747                                        在灾难面前，更见人品。     0
# 1361391                                                 好看     0
# 2019277                                      我想这大概是动画电影的极致     0
# 1917009                                           真是人生的电影啊     0
# 1711591                                          没看特地来打个一星     0
# 1249319    充满韩式幽默的电影，蒙太奇等运用很专业，觉得韩寒费了不少心思。怎么说呢，就像他的杂文，很韩寒。     0
# 2067896           生活就像一盒巧克力啊 我总是不知道接下来是什么电影还是挺有思想的 难得这么用心      0
