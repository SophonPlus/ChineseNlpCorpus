# %% [markdown]
# # baiduzhidao 说明
# 0. **下载地址：** [百度网盘](https://pan.baidu.com/s/1ZEu8CF6cc76rEwmM7NMzQg)
# 1. **数据概览：**
#     A. **8000多** 条保险行业问答数据
#     B. **4万** 条农业银行问答数据
#     C. **58.8万** 条保险行业问答数据
#     D. **20.3万** 条联通问答数据
#     E. **15.6万** 条电信问答数据
#     F. **3.6万** 条法律问答数据
#     G. **77万** 条金融行业问答数据
# 2. **推荐实验：** FAQ问答系统 文本分类
# 3. **数据来源：** 百度知道
# 4. **加工处理：**
#     1. 过滤了id、url、qid、reply_t、user字段
#     2. 对title、question、reply做了脱敏处理

# %%
import pandas as pd

# %%
path = 'baiduzhidao_文件夹_所在_路径'

# %% [markdown]
# ## 字段说明
#
# | 字段 | 说明 |
# | ---- | ---- |
# | title | 问题的标题 |
# | question | 问题内容（可为空） |
# | reply| 回复内容 |
# | is_best| 是否为页面上显示的最佳回答 |

# %% [markdown]
# # 1.baoxianzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
baoxianzhidao = pd.read_csv(path + 'baoxianzhidao_filter.csv')

# %%
baoxianzhidao.sample(n=20)
# Out:
#                            title  \
# 6762            新农合在本省和外省报销有分别吗?
# 7632                 成*生育报销需要几个月
# 1058     一岁孩子投保慧馨安选择十万保额的话保费一年多少
# 646          看见安邦长青树中的犹豫期，是什么意思？
# 5684                     能领失业金吗？
# 328    请问，我合肥的朋友买了康惠保，我在北*，也可以买吗
# 5563    平安保险如果在一个月内宽限期内生病住院还给报销吗
# 7040         住院医保保险，怎么报，需要些什么材料？
# 5174               厂里交了医保,家里要交吗?
# 2427           买车险电话直销和柜台办理有什么区别
# 857                 意外疾病终身保险买哪种好
# 44          周末赔闺女体验下野外运动，有没有亲子保险
# 4852                     意外险生效日期
# 5890      保险理赔主次责任赔偿标准是多少,有明文规定吗
# 2485          人民保险车险小额人伤保险申请需要什么
# 6981            企业不给员工缴纳保险给补助可以吗
# 3783  我三十八岁，交人寿保险鑫如意三年，每年两万，怎么领钱
# 6532                   网上怎么买汽车保险
# 4641                人寿保险退订手续费要多少
# 2195            哪些属于交强险，哪些又属于商业险
#
#                                                question  \
# 6762                                   新农合在本省和外省报销有分别吗?
# 7632                                        成*生育报销需要几个月
# 1058                                                NaN
# ...

# %% [markdown]
# ## 2.touzizhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
touzizhidao = pd.read_csv(path + 'touzizhidao_filter.csv')

# %%
touzizhidao.sample(n=20)
# Out:
#                          title  \
# 146853         在深*没有社保可以办信用卡吗？
# 177077                    光大银行
# 545291                不买社保可以吗？
# 77256          养老营利性和民办非营利性的区别
# 499795       用支付宝转账到邮政银行为什么有限额
# 248743                芝麻分贷款可靠吗
# 338008               社保职工编号怎么查
# 204326             爱联加油站旁边小额贷款
# 505009              网上贷款还不上怎么办
# 257302              如何查询房产是否落宗
# 228744          柯*亲馨家园公租房家具哪儿买
# 298131       有逾期可以贷款吗有逾期怎么办理贷款
# 488634  十几个网贷都逾期了还可以在农村信用社贷款吗？
# 424621             信用卡开户属于哪类服务
# 59031            买房子什么户型比较好？买房
# 124364          支付宝子账户可以申请贷款吗？
# 59825             有办过大学生助学贷款的吗
# 228741          如何选择最佳的住宅楼层和朝向
# 251256    工行信用卡申请15后没接到通知还是己受理
# 384979   外汇新手怎么玩赚钱，外汇操作交易保证金杠杆
#
#                                                  question  \
# 146853                                                NaN
# 177077                                               光大银行
# 545291  我想跟单位签订一个为期一年的“不买社保承诺书”，单位也答应说签了的话可以给一些补助，那请问一...
# ...

# %% [markdown]
# # 3.liantongzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
liantongzhidao = pd.read_csv(path + 'liantongzhidao_filter.csv')

# %%
liantongzhidao.sample(n=20)
# Out:
#                                                     title  \
# 116848                                        联通卡能用移动版手机吗
# 123102                        长*dr.com宽带客户端链接老是显示客户端认证失败1
# 7073                                  山*的4G联通手机号还有积分怎么用啊？
# 157527  苹果5SA##28更新最新版本后9.3.4最新版本，手机打开4G开关，4G联通卡，所在地区有...
# 168628                                          #0#55联通炫铃
# 39313                                为什么我的联通日租卡会自动开启视频流量包
# 159014                              联的3g流量套餐与4g的有什么区别？时候会
# 80618                              小米高仿版-m4(联通3g版)怎么切换中文？
# 9112                                联通里面的可用余额和可用预存款都是啥意思？
# 160608                            联通的流量还有3个g半年包,为什么显示超流量了
# 47922                                    手机昨天还用着今天怎么突然销户了
# 99981                                      3G能够提供业务主要包括哪些
# 31615                                          微信打开不了开通王*
# 168261                              2016iOS版联通手机营业厅怎么换套餐？
# 63829                           郴*市*南*五*广*联*营*厅店面位置及营*时间？
# ...

# %% [markdown]
# # 4.nonghangzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
nonghangzhidao = pd.read_csv(path + 'nonghangzhidao_filter.csv')

# %%
nonghangzhidao.sample(n=20)
# Out:
#                                title  \
# 18739            办农行的信用卡哪个是刷满五次免年费的？
# 31561                    农业快e付存款有风险吗
# 25850                         农业银行贷款
# 7998                 贷款购买完优信二手车贷款有问题
# 34471    最近手上有点结余，想做个投资，有没有好的理财产品推荐？
# 20105                 过期的身份证可以办银行卡吗？
# 25730  农业信用卡金穗QQ卡显示待邮寄个人什么时候可以收到短信拿卡
# 9896                       钱站现在能下款么？
# 27006                    我想贷款，那个平台好点
# 38354           有农业银行信用卡,怎么才能操作出来万捷贷
# 31937               淘宝网退款到农行银行卡要多久到账
# 13374                  搞什么我急用钱怎么登不上去
# 39662          农业银行手机银行交通罚款里标示码是什么意思
# 12670                    想要结婚了，没钱该咋办
# 4940                          你微信号好多
# 2531                       手机号变更多久生效
# 34728                     办存折必须要本人去吗
# 12500               大*住房公积金贷款手续费要交哪些
# 2136           贷款贷上亿靠谱吗，需要什么手续，最大额贷多
# 7659                      网贷在校园是合法的吗
#
#                                           question  \
# 18739                                          NaN
# 31561                                          NaN
# ...

# %% [markdown]
# # 5.financezhidao_filter.csv

# %% [markdown]
# ##  加载数据

# %%
financezhidao = pd.read_csv(path + 'financezhidao_filter.csv.csv')

# %%
financezhidao.sample(n=20)
# Out:
#                                                     title  \
# 138931                                     杭*.请教能做哪些公积金贷款
# 249873                                     公积金贷款怎样才能贷满50万
# 147445       我想办一张#####额度的招商信用卡业务员说分#2期还最后只需要还款#####是真的吗？
# 59137                                          芝麻分430能借钱吗
# 416558                                   银行卡忘在atm机里怎么联系银行
# 449306                                             个人贷款，急
# 741795                                     成*办理招行信用卡有哪些条件
# 390138                                         周末招商银行几点开门
# 114117                               我可以扬*公积金贷款多少年呢，多少钱–安
# 142226                                          请问手机借款怎么借
# 391486  今年办房贷，贷款已审批但由于政策原因目前仍未放款，未放款期间能办理车贷吗？办车贷会对房贷有影响吗？
# 740379                                  我的招行信用卡能不能在网上转账呢？
# 144470                                     泰融小鱼白条谁借过？放款快么
# 277874                                     ATM机上可以跨行现金存款吗
# 630023                                只提供了工资流水办招商信用卡，能通过吗
# ...

# %% [markdown]
# # 5.lawzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
lawzhidao = pd.read_csv(path + 'lawzhidao_filter.csv.csv')

# %%
lawzhidao.sample(n=20)
# Out:
#                                                  title  \
# 7155                                 ,伤病关系为55%,医疗费怎么赔偿
# 15379                                   想离婚，男方需要给女方赔偿吗
# 7505                         我朋友卖淫不知道自己得梅毒被抓了，我想问一下会怎么
# 30779                          男方要求离婚，女方还在哺乳期内，可以提出赔偿吗
# 22416                        工人工伤死亡，除了社会保险局赔偿外，工厂还要赔偿吗
# 16089                                 我想离婚不回家可不可以办离婚手续
# 14698                                       裸照威胁未成功判多久
# 13211                   婚前自己贷款买房婚后自己还款几年后结婚离婚后女方会分财产吗？
# 3958                                   医疗过错协商解决的步骤是怎样的
# 22329                        在休闲会所上班的,没有签合同辞工不批能告劳动局吗?
# 12542  请问！别人问我借的钱没有欠条，但我有短信内容证明与支付宝转账证明，请问我可以通过法律要回钱嘛？
# 5894                                      有案底怎么注册滴滴专车？
# 34051                                 9岁幼童突然失踪，是出走还是绑架
# 8891                                   只有离婚协议没有离婚证可否买房
# 28725                               今天下午在小巷子里被人强奸了，怎么办
# 32949                         公安机关非法限制人身自由，应该找什么部门，人现在
# ...

# %% [markdown]
# # 6.anhuidianxinzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
anhuidianxinzhidao = pd.read_csv(path + 'anhuidianxinzhidao_filter.csv.csv')

# %%
anhuidianxinzhidao.sample(n=20)
# Out:
#                                                  title  \
# 26897                                   电信营业厅签到为什么没有了?
# 84441                                     怎么还原回收站删除的文件
# 85433                                ip########us内屏多少钱
# 76208                        本月通信费100元,余额18元,共享话费108元是
# 29313                              下载游戏4.2mb/s相当于多少兆宽带
# 113939  电信ITV包月39元的开通后，有些是不是会按集数收费？现在还有这种情况吗求急结现在都不敢看了
# 22113                                      22#74兆是多少流量
# 121433                                如何在电信网上营业厅查询通话记录
# 24510                                 ip###e8港版支持电信4g吗
# 89910                             苹果6splus升级10.3.3像素多少
# 41357                          华为HG###0C恢复出厂设置/复位怎么操作？
# 47930                         中国电信网上营业厅可不可以查到短信内容/中国电信
# 127349                             012#######89是哪里电话号码
# 101542                                      华为手机不断黑屏重启
# 70281                                 ip###e8支持电信800m吗
# 135845                                   87####17是哪的电话
# ...

# %% [markdown]
# # 7.baoxianzhidao_filter.csv

# %% [markdown]
# ## 加载数据

# %%
baoxianzhidao = pd.read_csv(path + 'baoxianzhidao_filter.csv.csv')

# %%
baoxianzhidao.sample(n=20)
# Out:
#                                       title  \
# 279                     请问下，投保康惠保之前需要进行体检吗？
# 5688  喝了酒开车，结果撞在栏杆上了；车撞坏了，保险公司是否会赔偿？买的是商业保险
# 8124                现在买百年康惠保重疾险，必须要去保险公司弄吗？
# 6411                       公司商业保险报销能报销检查费用吗
# 5615             我坐的摩托车和汽车相撞,汽车负主要责任,我该怎样理赔
# 4789                      新车刚刚交了一年的强制险可以改名吗
# 4007                   闯红灯造成对方车辆受损,保险公司会陪吗?
# 6324                        养老保险怎么自己查询缴费了吗？
# 5929                   不在护口所在地买保险,回原籍住院怎么报俏
# 6600                     第三方责任险和不计免赔险撞人了怎么算
# 3236                             车险一年可以报销几次
# 7151                             阳光电话车险怎么样？
# 1635                      平安福保险怎么样？给老年人买可以吗
# 4165                        城镇居民医疗保险报销比例是多少
# 606                       安*长青树是不是只能赔付一种小病？
# 5658            我开小车撞了摩托车，人员受伤第三者怎么理赔，强保怎么赔
# 6881                   犹豫期内如何退保?犹豫期退保要注意什么?
# 7347                         企业保险和事业保险有什么区别
# 365                        投保哆啦A保之前需要进行体检吗？
# 5333                小学生在课堂上不小心致他人受伤保险公司有赔付吗
#
# ...
